# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cust = pd.read_csv(r"D:\Python with Data Analysis\PythonProject\PythonProject\CSV_s1\customers.csv")

# %%
cust.head()
# Out:
#    'custno' 'firstname' 'lastname' 'gender'  'age' 'profession'  'contactNo'  \
# 0         1      Leslie       Bass        F     27            B        37307
# 1         2        Judy      Burks        M     53            S        84759
# 2         3      Marsha      Doyle        F     48            B        80932
# 3         4      Alexis     Battle        M     27            S        71701
# 4         5      Martha      Combs        F     49            B        83947
#
#                 'emailId'   'city'    'state' 'isActive'        'createdDate'  \
# 0  endslost@everyma1l.org   Gibson   Dellwood          Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue          Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla          Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis          Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood          Y  2017-05-15 07:34:35
#
#          'UpdatedDate'
# ...

# %%
prod = pd.read_csv(r"D:\Python with Data Analysis\PythonProject\PythonProject\CSV_s1\products.csv")

# %%
prod.head()
# Out:
#    'productno' 'productName' 'Description' 'isActive'        'createdDate'  \
# 0            1      Product1    pgqorighfa          Y  2017-04-03 07:58:55
# 1            2      Product2    lmndaaweth          Y  2017-09-21 12:38:31
# 2            3      Product3    urifeubrhh          Y  2017-09-08 10:32:12
# 3            4      Product4    rlpcjxfarp          Y  2017-05-22 05:29:27
# 4            5      Product5    hzcpozsgfc          Y  2017-02-02 08:40:29
#
#          'UpdatedDate'
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
trans = pd.read_csv(r"D:\Python with Data Analysis\PythonProject\PythonProject\CSV_s1\transactions.csv")

# %%
trans.head()
# Out:
#    'txnno'            'txndate'  'custno'  'amount'  'productno' 'spendby'
# 0        1  2017-10-18 12:31:45       923      2559          376      Card
# 1        2  2017-10-18 12:31:45       219      1706          151      Card
# 2        3  2017-10-18 12:31:45       927      3462          707      Cash
# 3        4  2017-10-18 12:31:45       806       865          539      Card
# 4        5  2017-10-18 12:31:45       958      2494           25      Card

# %%
cust.dtypes
# Out:
# 'custno'          int64
# 'firstname'      object
# 'lastname'       object
# 'gender'         object
# 'age'             int64
# 'profession'     object
# 'contactNo'       int64
# 'emailId'        object
# 'city'           object
# 'state'          object
# 'isActive'       object
# 'createdDate'    object
# 'UpdatedDate'    object
# dtype: object

# %%
prod.dtypes
# Out:
# 'productno'       int64
# 'productName'    object
# 'Description'    object
# 'isActive'       object
# 'createdDate'    object
# 'UpdatedDate'    object
# dtype: object

# %%
trans.dtypes
# Out:
# 'txnno'         int64
# 'txndate'      object
# 'custno'        int64
# 'amount'        int64
# 'productno'     int64
# 'spendby'      object
# dtype: object

# %%
print(cust.shape)
print(prod.shape)
print(trans.shape)
# Out:
# (1000, 13)
# (1000, 6)
# (1000, 6)

# %%
prod_trans = pd.merge(prod,trans,on="'productno'",how="inner")

# %%
prod_trans
# Out:
#      'productno' 'productName' 'Description' 'isActive'        'createdDate'  \
# 0              1      Product1    pgqorighfa          Y  2017-04-03 07:58:55
# 1              2      Product2    lmndaaweth          Y  2017-09-21 12:38:31
# 2              3      Product3    urifeubrhh          Y  2017-09-08 10:32:12
# 3              4      Product4    rlpcjxfarp          Y  2017-05-22 05:29:27
# 4              4      Product4    rlpcjxfarp          Y  2017-05-22 05:29:27
# ..           ...           ...           ...        ...                  ...
# 995          995    Product995    fyocaaajef          Y  2017-02-20 11:05:41
# 996          996    Product996    acvxzpvhyu          Y  2017-09-09 07:49:14
# 997          997    Product997    eguyggimfm          Y  2017-09-14 12:13:29
# 998          998    Product998    hagbslxugf          Y  2017-04-20 06:25:03
# 999          998    Product998    hagbslxugf          Y  2017-04-20 06:25:03
#
# ...

# %%
cust_trans = cust.merge(prod_trans,on="'custno'",how="outer")

# %%
cust_trans.head()
# Out:
#    'custno' 'firstname' 'lastname' 'gender'  'age' 'profession'  'contactNo'  \
# 0         1      Leslie       Bass        F     27            B        37307
# 1         2        Judy      Burks        M     53            S        84759
# 2         2        Judy      Burks        M     53            S        84759
# 3         3      Marsha      Doyle        F     48            B        80932
# 4         4      Alexis     Battle        M     27            S        71701
#
#                 'emailId'   'city'    'state'  ... 'productno' 'productName'  \
# 0  endslost@everyma1l.org   Gibson   Dellwood  ...         NaN           NaN
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue  ...       136.0    Product136
# 2  rfleming@hotma1l.co.uk  Suwanee     Trabue  ...       842.0    Product842
# 3    arethe53@ma1lbox.net    Perry  Moxadarla  ...       345.0    Product345
# 4      ofcame@ma1lbox.org   Morven     Dennis  ...       144.0    Product144
#
# ...

# %%
cust_trans.isnull().sum()
# Out:
# 'custno'             0
# 'firstname'          0
# 'lastname'           0
# 'gender'             0
# 'age'                0
# 'profession'         0
# 'contactNo'          0
# 'emailId'            0
# 'city'               0
# 'state'              4
# 'isActive'_x         0
# 'createdDate'_x      0
# 'UpdatedDate'_x      0
# 'productno'        352
# 'productName'      352
# 'Description'      352
# 'isActive'_y       352
# 'createdDate'_y    352
# 'UpdatedDate'_y    352
# 'txnno'            352
# 'txndate'          352
# 'amount'           352
# 'spendby'          352
# dtype: int64

# %%
cust_trans.dropna(axis=0)
# Out:
#       'custno' 'firstname' 'lastname' 'gender'  'age' 'profession'  \
# 1            2        Judy      Burks        M     53            S
# 2            2        Judy      Burks        M     53            S
# 3            3      Marsha      Doyle        F     48            B
# 4            4      Alexis     Battle        M     27            S
# 5            4      Alexis     Battle        M     27            S
# ...        ...         ...        ...      ...    ...          ...
# 1342       992      Tamara       Shaw        M     32            S
# 1346       996     Roxanne  Velazquez        M     37            S
# 1347       997     Kristen       Wall        F     20            B
# 1348       997     Kristen       Wall        F     20            B
# 1350       999       Betty       Leon        F     23            B
#
#       'contactNo'                'emailId'               'city'    'state'  \
# 1           84759   rfleming@hotma1l.co.uk              Suwanee     Trabue
# ...

# %%
cust_trans.isnull().sum()
# Out:
# 'custno'             0
# 'firstname'          0
# 'lastname'           0
# 'gender'             0
# 'age'                0
# 'profession'         0
# 'contactNo'          0
# 'emailId'            0
# 'city'               0
# 'state'              4
# 'isActive'_x         0
# 'createdDate'_x      0
# 'UpdatedDate'_x      0
# 'productno'        352
# 'productName'      352
# 'Description'      352
# 'isActive'_y       352
# 'createdDate'_y    352
# 'UpdatedDate'_y    352
# 'txnno'            352
# 'txndate'          352
# 'amount'           352
# 'spendby'          352
# dtype: int64

# %%
cust_trans
# Out:
#       'custno' 'firstname' 'lastname' 'gender'  'age' 'profession'  \
# 0            1      Leslie       Bass        F     27            B
# 1            2        Judy      Burks        M     53            S
# 2            2        Judy      Burks        M     53            S
# 3            3      Marsha      Doyle        F     48            B
# 4            4      Alexis     Battle        M     27            S
# ...        ...         ...        ...      ...    ...          ...
# 1347       997     Kristen       Wall        F     20            B
# 1348       997     Kristen       Wall        F     20            B
# 1349       998       Terry  Blackwell        M     28            S
# 1350       999       Betty       Leon        F     23            B
# 1351      1000      Connie    Andrews        M     47            S
#
#       'contactNo'                    'emailId'               'city'  \
# 0           37307       endslost@everyma1l.org               Gibson
# ...

# %%
count = cust_trans.groupby(["'custno'","'firstname'","'lastname'"]).size()

# %%
purchased = count[count > 3]

# %%
purchased
# Out:
# 'custno'  'firstname'  'lastname'
# 4         Alexis       Battle        4
# 86        Bonnie       McCall        4
# 167       Alice        Blake         4
# 187       Alan         Anthony       4
# 237       Dawn         West          4
# 241       Derrick      Pearson       5
# 321       Crystal      Le            4
# 326       Heidi        Stanley       4
# 331       Cynthia      Harrison      4
# 356       Mitchell     Mason         4
# 391       Keith        Church        5
# 537       Jake         Bush          4
# 558       Lois         Todd          4
# 578       Christine    Murray        4
# 709       Kyle         Haynes        4
# 735       James        Payne         4
# 753       Denise       Stokes        4
# 828       Katrina      Barber        4
# 989       Ronald       Mayo          4
# dtype: int64

# %%
top5_products = cust_trans["'productName'"].value_counts().head(5)

# %%
top5_products
# Out:
# 'productName'
# Product427    5
# Product768    5
# Product82     5
# Product900    5
# Product723    4
# Name: count, dtype: int64

# %%
top5_transactions = cust_trans.sort_values("'amount'", ascending=False).head(5)

# %%
top5_transactions
# Out:
#      'custno' 'firstname' 'lastname' 'gender'  'age' 'profession'  \
# 912       670       Vicki      Frank        M     27            S
# 605       448       Joyce     Slater        M     57            S
# 404       305      Janice  Valentine        F     62            B
# 300       230        Jean  Singleton        M     64            S
# 386       287      Alissa        Roy        F     18            B
#
#      'contactNo'               'emailId'       'city'     'state'  ...  \
# 912        84305  jcolon28@everyma1l.net     Colquitt   Pennisula  ...
# 605        47613   spittman@somema1l.biz       Metter   Woodbrook  ...
# 404        23111       jglover@gma1l.biz      Tarboro  Thornberry  ...
# 300        30274      listwhat@gma1l.com     Rockmart     Warwick  ...
# 386        85584    bengland@yah00.co.uk  East Dublin    Hideaway  ...
#
#     'productno' 'productName' 'Description'  'isActive'_y  \
# 912       509.0    Product509    vxzqcrhjxi             Y
# ...

# %%
cust_trans["'profession'"].unique()
# Out:
# array(['B', 'S'], dtype=object)

# %%
cust["'age'"].sort_values(ascending=False).head(1)
# Out:
# 500    64
# Name: 'age', dtype: int64

# %%
cust_trans.loc[cust_trans["'custno'"] == 923,
               ["'custno'", "'gender'", "'age'", "'profession'", "'contactNo'", "'productno'", "'productName'", "'txndate'", "'spendby'", "'amount'"]]
# Out:
#       'custno' 'gender'  'age' 'profession'  'contactNo'  'productno'  \
# 1253       923        F     46            B        25436        113.0
# 1254       923        F     46            B        25436        376.0
# 1255       923        F     46            B        25436        644.0
#
#      'productName'            'txndate' 'spendby'  'amount'
# 1253    Product113  2017-10-18 12:31:46      Card    2303.0
# 1254    Product376  2017-10-18 12:31:45      Card    2559.0
# 1255    Product644  2017-10-18 12:31:46      Cash    4553.0

# %%
readtrans = pd.read_csv(r"D:\Python with Data Analysis\PythonProject\PythonProject\PSV_s2\transactions.txt")

# %%
readtrans.head()
# Out:
#    1|2017-10-18 12:31:45|923|2559|376|Card
# 0  2|2017-10-18 12:31:45|219|1706|151|Card
# 1  3|2017-10-18 12:31:45|927|3462|707|Cash
# 2   4|2017-10-18 12:31:45|806|865|539|Card
# 3   5|2017-10-18 12:31:45|958|2494|25|Card
# 4   6|2017-10-18 12:31:45|37|3782|603|Cash

# %%
readprod = pd.read_csv(r"D:\Python with Data Analysis\PythonProject\PythonProject\PSV_s2\products.txt")

# %%
readprod.head()
# Out:
#   1|Product1|pgqorighfa|Y|2017-04-03 07:58:55|2017-10-18 12:12:38
# 0  2|Product2|lmndaaweth|Y|2017-09-21 12:38:31|20...
# 1  3|Product3|urifeubrhh|Y|2017-09-08 10:32:12|20...
# 2  4|Product4|rlpcjxfarp|Y|2017-05-22 05:29:27|20...
# 3  5|Product5|hzcpozsgfc|Y|2017-02-02 08:40:29|20...
# 4  6|Product6|ezhxpqxqdg|Y|2017-01-13 12:47:01|20...

# %%
readcst = pd.read_csv(r"D:\Python with Data Analysis\PythonProject\PythonProject\PSV_s2\customers.txt")

# %%
readcst.head()
# Out:
#   1|Leslie|Bass|F|27|B|37307|endslost@everyma1l.org|Gibson|Dellwood|Y|2017-09-21 12:38:22|2017-10-18 12:12:28
# 0  2|Judy|Burks|M|53|S|84759|rfleming@hotma1l.co....
# 1  3|Marsha|Doyle|F|48|B|80932|arethe53@ma1lbox.n...
# 2  4|Alexis|Battle|M|27|S|71701|ofcame@ma1lbox.or...
# 3  5|Martha|Combs|F|49|B|83947|camedied@everyma1l...
# 4  6|Marilyn|Nguyen|M|57|S|72274|discoveredlist82...

# %%
readcstjson = pd.read_json(r"D:\Python with Data Analysis\PythonProject\PythonProject\JSON_s3\customers.json",lines=True)

# %%
readcstjson.head()
# Out:
#    custno  firstname lastname  gender  age          profession      contactNo  \
# 0       1        Dai    Noble       2   53     Human Resources  1644101928099
# 1       2        Kay     Wise       2   26    Public Relations  1674031917099
# 2       3       Amir     Pace       1   43  Customer Relations  1636050509999
# 3       4  Sebastian    Lopez       2   32  Customer Relations  1666010108899
# 4       5      Brian   Maddox       1   40   Quality Assurance  1646080399299
#
#                         emailId             city       state  isActive  \
# 0  eu.lacus.Quisque@loremac.com           Berlin      Berlin         1
# 1          ridiculus@Sednunc.ca        Oldenzaal  Overijssel         2
# 2    quam.Pellentesque@erat.edu          Cobourg     Ontario         2
# 3           magna@venenatis.net       Te Awamutu          NI         1
# 4         ac.facilisis@Duis.com  Greater Sudbury     Ontario         2
#
#   createdDate UpdatedDate
# 0  2017-03-01  2018-08-25
# ...

# %%
readprodjson = pd.read_json(r"D:\Python with Data Analysis\PythonProject\PythonProject\JSON_s3\products.json",lines=True)

# %%
readprodjson.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1        101          Toyota         six         2  2017-10-03  2017-11-13
# 2        102  General Motors         two         1  2017-09-18  2017-11-03
# 3        103         Renault       eight         2  2017-10-05  2017-11-13
# 4        104        Kenworth       three         1  2017-05-03  2017-11-04

# %%
readtransjson = pd.read_json(r"D:\Python with Data Analysis\PythonProject\PythonProject\JSON_s3\transactions.json",lines=True)

# %%
readtransjson.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-07-31      71     181         19        2
# 1      2  2017-04-02      44     401         48        2
# 2      3  2018-01-31      45    1808         44        2
# 3      4  2018-04-02      62      65         22        2
# 4      5  2017-08-17      88    1149         74        2

# %%
readcstxml = pd.read_xml(r"D:\Python with Data Analysis\PythonProject\PythonProject\XML_s4\customers.xml")

# %%
readcstxml.head()
# Out:
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       5    Arthur     Hurst       2   41        Tech Support  1681021022799
#
#                           emailId             city         state  isActive  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire         1
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU         1
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI         1
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H         1
# 4             in@commodoipsum.org        San Diego       Cartago         2
#
#   createdDate UpdatedDate
# ...

# %%
readprodxml = pd.read_xml(r"D:\Python with Data Analysis\PythonProject\PythonProject\XML_s4\products.xml")

# %%
readprodxml.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1        101           Honda       eight         1  2017-04-10  2017-11-11
# 2        102             GMC       three         2  2017-02-09  2017-11-17
# 3        103           Lexus       eight         2  2017-06-01  2017-11-04
# 4        104           Smart        five         2  2017-08-10  2017-11-16

# %%
readtxnxml = pd.read_xml(r"D:\Python with Data Analysis\PythonProject\PythonProject\XML_s4\transactions.xml")

# %%
readtxnxml.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-09-16       6     576         73        1
# 1      2  2018-02-11      96    1038         40        2
# 2      3  2017-06-13      17     673          2        1
# 3      4  2017-07-25      89    1284        100        2
# 4      5  2017-06-15       9    1685         56        2
